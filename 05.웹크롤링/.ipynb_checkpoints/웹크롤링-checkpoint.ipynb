# %% [markdown]
# # 웹크롤링 - 멜론사이트

# %%
import pandas as pd
#웹 브라우저를 조작
#웹 브라우저에 보이는 HTML 태그 속에서
#텍스트 데이터를 분리해서 가지고오는 라이브러리


#selenium 설치 명령: conda install -c conda-forge selenium - 최적화 버전( -c 채널)
#conda install로 설치가 안되면 : pip install selenium - 최신버전
#관리자 권한 혹은 ! 사용해서`
from selenium import webdriver

# %%
#구글 크롬 드라이브 다운로드하기
#https://sites.google.com/a/chromium.org/chromedriver/downloads

# %%
driver = webdriver.Chrome("C:/Program Files/ChromeDrive_exe/chromedriver.exe")
# Out:
# C:\Users\ad\AppData\Local\Temp/ipykernel_11872/559273182.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/Program Files/ChromeDrive_exe/chromedriver.exe")

# %%
#웹 url로 접근하기
url = "https://www.naver.com"
driver.get(url)

# %%
#웹페이지(html) 읽어들이기
html=driver.page_source
html
# Out:
# '<html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"><head><script async="" type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js"></script> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:u
# ...

# %%
#html
<html>
    <head>
    </head>
    <body>
        <h1> 우리동네시장</h1>
            <div class = 'sale'>
                <p id='fruits1' class='fruits'>
                    <span class = 'name'> 바나나 </span>
                    <span class = 'price'> 3000원 </span>
                    <span class = 'inventory'> 500개 </span>
                    <span class = 'store'> 가나다상회 </span>
                    <a href = 'http://bit.ly/forPlaywithData' > 홈페이지 </a>
                </p>
            </div>
            <div class = 'prepare'>
                <p id='fruits2' class='fruits'>
                    <span class ='name'> 파인애플 </span>
                </p>
            </div>
    </body>
</html>
# Out:
#   File "C:\Users\ad\AppData\Local\Temp/ipykernel_11872/3881975149.py", line 2
#     <html>
#     ^
# SyntaxError: invalid syntax

# %%
#html 문자열로 저장

html = '''<html>
            <head>
            </head>
            <body>
                <h1> 우리동네시장</h1>
                    <div class = 'sale'>
                        <p id='fruits1' class='fruits'>
                            <span class = 'name'> 바나나 </span>
                            <span class = 'price'> 3000원 </span>
                            <span class = 'inventory'> 500개 </span>
                            <span class = 'store'> 가나다상회 </span>
                            <a href = 'http://bit.ly/forPlaywithData' > 홈페이지 </a>
                        </p>
                    </div>
                    <div class = 'prepare'>
                        <p id='fruits2' class='fruits'>
                            <span class ='name'> 파인애플 </span>
                        </p>
                    </div>
            </body>
            </html>'''

# %%
html #문자열

# %%
#BeautifulSoup
#문자열 데이터를 HTML 형식으로 읽어드리고
#정보를 쉽게 찾을 수 있도록 도와주는 라이브러리
#HTML 문서 해석
from bs4 import BeautifulSoup as bs

# %%
#html.parser: 문자열 형태의 html 파일을 실제 html형식으로 변환
soup = BeautifulSoup(html, "html.parser")
soup

# %%
#span이라는 태그 조회
tags_span = soup.select("span")
tags_span

# %%
tags_p = soup.select("p")
tags_p

# %%
#id를 통해 접근하기
ds_fruits1 = soup.select("#fruits1")
ds_fruits1

# %%
#클래스를 통해 접근하기
#중복값 존재가능성있음

class_price = soup.select(".price")
class_price

# %%
soup.select("span.name")

# %%
#태그 구조 중 자식/자손 의미를 부여하는 기호  ' > ' 
#자식: 직계 / 자손: 하위 모든 것들

#id 속성이 fruist1을 가지는 자식 중 span이라는 태그의 속성 중 클래스 이름이 name이라는 태그 조회
soup.select("#fruits1 > span.name")

# %% [markdown]
# ##### 문제
#
# div태그의 클래스 속성의 이름이 sale인 자식 중에 <br>
# id의 이름이 fruist1인 태그의 자식을 찾아서<br>
# span태그의 클래스 속성이 name인 태그를 조회하시오

# %%
soup.select("div.sale > #fruits1 > span.name")

# %%
#스페이스 : 자손의미
#div태그의 클래스 속성이 sale인 자식의 자손들 중 span태그의 name라는 태그를 가진 것
soup.select("div.sale span.name")

# %%
tags= soup.select("span.name")
tags

# %%
tags[0]

# %%
tags[1]

# %%
#범위를 이용하는 것
for i in range(0, len(tags), 1) :
    print(tags[i])

# %%
#값을 이용하는 것
for tag in tags :
    print(tag)

# %%
tag

# %%
tag.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11872/3372068644.py in <module>
# ----> 1 tag.text
#
# NameError: name 'tag' is not defined

# %%
#리스트로 조회한다는 것
tag["class"][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11872/2618542945.py in <module>
#       1 #리스트로 조회한다는 것
# ----> 2 tag["class"][0]
#
# NameError: name 'tag' is not defined

# %%
#  a태그 사용하기  - 링크값 가짐
tags = soup.select("a")
tags
# Out:
# [<a href="#gnb_menu">메뉴</a>,
#  <a href="#conts_section">본문</a>,
#  <a href="#footer">하단 정보</a>,
#  <a class="menu01 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V08&amp;ACTION_AF_CLICK=V1" href="https://ticket.melon.com/main/index.htm" title="멜론 티켓"><span>멜론 티켓</span></a>,
#  <a class="menu01 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=B01&amp;ACTION_AF_CLICK=V1" href="/commerce/pamphlet/web/sale_listMainView.htm" title="이용권구매"><span>이용권구매</span></a>,
#  <a class="menu02 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V06&amp;ACTION_AF_CLICK=V1" href="/event/vip/index.htm" title="멜론혜택관"><span>멜론혜택관</span></a>,
#  <a class="menu03 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=B03&amp;ACTION_AF_CLICK=V1" href="/event/index.htm" title="이벤트"><span>이벤트</span></a>,
# ...

# %%
tags[0].text
# Out:
# '메뉴'

# %%
tags[0]["href"]
# Out:
# '#gnb_menu'

# %% [markdown]
# ---

# %% [markdown]
#  # 멜론 노래 순위 정보 클로링 하기

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome("C:/Program Files/ChromeDrive_exe/chromedriver.exe")
# Out:
# C:\Users\ad\AppData\Local\Temp/ipykernel_11872/559273182.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/Program Files/ChromeDrive_exe/chromedriver.exe")

# %%
url = "http://www.melon.com/chart/index.htm"
driver.get(url)

# %%
from bs4 import BeautifulSoup

# %%
html = driver.page_source
html
# Out:
# '<html lang="ko" class="narrow-screen"><head>\n\t\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t\n\n\t\n\n\t\n\n\t<title>멜론차트&gt;TOP100&gt;멜론</title>\n\t<meta name="keywords" content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널">\n\t<meta name="description" content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!">\n\t<meta name="naver-site-verification" content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b">\n\t<meta name="google-site-verification" content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc">\n\t<meta property="fb:app_id" content="357952407588971">\n\t<meta property="og:title" content="Melon">\n\t<meta property="og:image" content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png">\n\t<meta property="og:description" content="음악이 필요한 순간, 멜론">\n\t<meta property="og:url" content="http://www.melon.com/ch
# ...

# %%
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <html class="narrow-screen" lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;TOP100&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/index.htm" property="og:url"/>
# ...

# %%
songs = soup.select("tr")
songs
# Out:
# [<tr>
#  <th scope="col">
#  <div class="wrap t_right"><input class="input_check d_checkall" title="곡 목록 전체 선택" type="checkbox"/></div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center"><span class="rank">순위</span></div>
#  </th>
#  <th scope="col">
#  <div class="wrap none">순위등락</div>
#  </th>
#  <th scope="col">
#  <div class="wrap none">앨범이미지</div>
#  </th>
#  <th scope="col">
#  <div class="wrap none">곡 상세가기</div>
#  </th>
#  <th scope="col">
#  <div class="wrap pd_l_12">곡정보</div>
#  </th>
#  <th scope="col">
#  <div class="wrap pd_l_12">앨범</div>
#  </th>
#  <th scope="col">
#  <div class="wrap pd_l_30">좋아요</div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center">듣기</div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center">담기</div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center">다운</div>
#  </th>
#  <th scope="col">
#  <div class="wrap t_center">뮤비</div>
#  </th>
#  </tr>,
#  <tr class="lst50" data-song-no="34626109" id="lst50">
# ...

# %%
len(soup.select("tr"))
# Out:
# 101

# %%
soup.select("tr")[0]
# Out:
# <tr>
# <th scope="col">
# <div class="wrap t_right"><input class="input_check d_checkall" title="곡 목록 전체 선택" type="checkbox"/></div>
# </th>
# <th scope="col">
# <div class="wrap t_center"><span class="rank">순위</span></div>
# </th>
# <th scope="col">
# <div class="wrap none">순위등락</div>
# </th>
# <th scope="col">
# <div class="wrap none">앨범이미지</div>
# </th>
# <th scope="col">
# <div class="wrap none">곡 상세가기</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_12">곡정보</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_12">앨범</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_30">좋아요</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">듣기</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">담기</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">다운</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">뮤비</div>
# </th>
# </tr>

# %%
soup.select("tr")[1]
# Out:
# <tr class="lst50" data-song-no="34626109" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="INVU 곡 선택" type="checkbox" value="34626109"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10863559');" title="INVU - The 3rd Album">
# <img alt="INVU - The 3rd Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/108/63/559/10863559_20220214160739_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# ...

# %%
soup.select("tr")[2]
# Out:
# <tr class="lst50" data-song-no="34061322" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="사랑은 늘 도망가 곡 선택" type="checkbox" value="34061322"/></div></td>
# <td><div class="wrap t_center"><span class="rank">2</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10735654');" title="신사와 아가씨 OST Part.2">
# <img alt="신사와 아가씨 OST Part.2 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/107/35/654/10735654_20211008114339_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# ...

# %%
#리스트에서 범위 지정
songs=soup.select("tr")[1: ]
len(songs)
# Out:
# 100

# %%
song = songs[0]
song
# Out:
# <tr class="lst50" data-song-no="34626109" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="INVU 곡 선택" type="checkbox" value="34626109"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10863559');" title="INVU - The 3rd Album">
# <img alt="INVU - The 3rd Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/108/63/559/10863559_20220214160739_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# ...

# %%
song.select("a")
# Out:
# [<a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10863559');" title="INVU - The 3rd Album">
#  <img alt="INVU - The 3rd Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/108/63/559/10863559_20220214160739_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34626109');" title="INVU 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('1000002721',34626109);" title="INVU 재생">INVU</a>,
#  <a href="javascript:melon.link.goArtistDetail('236797');" title="태연 (TAEYEON) - 페이지 이동">태연 (TAEYEON)</a>,
#  <a href="javascript:melon.link.goArtistDetail('236797');" title="태연 (TAEYEON) - 페이지 이동">태연 (TAEYEON)</a>,
#  <a href="javascript:melon.link.goAlbumDetail('10863559');" title="INVU - The 3rd Album - 페이지 이동">INVU - The 3rd Album</a>]

# %%
song2 = song.select("a")[2]
song2.text
# Out:
# 'INVU'

# %%
song.select("div.ellipsis.rank01 > span > a")[0].text
# Out:
# 'INVU'

# %%
#가수 이름만 가지고 오기
song.select("div.ellipsis.rank02>a")[0].text
# Out:
# '태연 (TAEYEON)'

# %%
songs[1].select("div.ellipsis.rank02>a")[0].text
# Out:
# '임영웅'

# %%
#100개 데이터의 제목과 가수이름을 출력해주세여
#출력 형태 : 제목[], 가수[]



for song in songs :
    #노래 제목만 가지고 오기
    title = song.select("div.ellipsis.rank01 > span > a")[0].text
    
    #가수 이름만 가지고 오기
    singer = song.select("div.ellipsis.rank02 > a")[0].text
    
    print("순위[{}],제목[{}], 가수[{}]".format(i,title, singer))
    
    #i +=1 =>  i = i + 1
    i += 1
# Out:
# 순위[99],제목[INVU], 가수[태연 (TAEYEON)]
# 순위[100],제목[사랑은 늘 도망가], 가수[임영웅]
# 순위[101],제목[취중고백], 가수[김민석 (멜로망스)]
# 순위[102],제목[듣고 싶을까], 가수[MSG워너비(M.O.M)]
# 순위[103],제목[언제나 사랑해], 가수[케이시 (Kassy)]
# 순위[104],제목[RUN2U], 가수[STAYC(스테이씨)]
# 순위[105],제목[abcdefu], 가수[GAYLE]
# 순위[106],제목[ELEVEN], 가수[IVE (아이브)]
# 순위[107],제목[너, 너 (N번째 연애 X 휘인 (Whee In))], 가수[휘인 (Whee In)]
# 순위[108],제목[SMILEY (Feat. BIBI)], 가수[YENA (최예나)]
# 순위[109],제목[Step Back], 가수[GOT the beat]
# 순위[110],제목[회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)], 가수[sokodomo]
# 순위[111],제목[다정히 내 이름을 부르면], 가수[경서예지]
# 순위[112],제목[이제 나만 믿어요], 가수[임영웅]
# 순위[113],제목[리무진 (Feat. MINO) (Prod. GRAY)], 가수[BE'O (비오)]
# 순위[114],제목[호랑수월가], 가수[탑현]
# 순위[115],제목[눈이 오잖아(Feat.헤이즈)], 가수[이무진]
# 순위[116],제목[STAY], 가수[The Kid LAROI]
# 순위[117],제목[신호등], 가수[이무진]
# 순위[118],제목[Counting Stars (Feat. Beenzino)], 가수[BE'O (비오)]
# 순위[119],제목[다시 사랑한다면 (김필 Ver.)], 가수[임영웅]
# 순위[120],제목[어제처럼], 가수[폴킴]
# 순위[121],제목[Dreams Come True], 가수[aespa]
# 순위[122],제목[Next Level], 가수[aespa]
# ...

# %%
for i in range(0, len(songs)) :
    
    title = songs[i].select("div.ellipsis.rank01 > span > a")[0].text
    singer = songs[i].select("div.ellipsis.rank02 > a")[0].text
    
    print("순위[{}],제목[{}], 가수[{}]".format(i+1,title, singer))
# Out:
# 순위[1],제목[INVU], 가수[태연 (TAEYEON)]
# 순위[2],제목[사랑은 늘 도망가], 가수[임영웅]
# 순위[3],제목[취중고백], 가수[김민석 (멜로망스)]
# 순위[4],제목[듣고 싶을까], 가수[MSG워너비(M.O.M)]
# 순위[5],제목[언제나 사랑해], 가수[케이시 (Kassy)]
# 순위[6],제목[RUN2U], 가수[STAYC(스테이씨)]
# 순위[7],제목[abcdefu], 가수[GAYLE]
# 순위[8],제목[ELEVEN], 가수[IVE (아이브)]
# 순위[9],제목[너, 너 (N번째 연애 X 휘인 (Whee In))], 가수[휘인 (Whee In)]
# 순위[10],제목[SMILEY (Feat. BIBI)], 가수[YENA (최예나)]
# 순위[11],제목[Step Back], 가수[GOT the beat]
# 순위[12],제목[회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)], 가수[sokodomo]
# 순위[13],제목[다정히 내 이름을 부르면], 가수[경서예지]
# 순위[14],제목[이제 나만 믿어요], 가수[임영웅]
# 순위[15],제목[리무진 (Feat. MINO) (Prod. GRAY)], 가수[BE'O (비오)]
# 순위[16],제목[호랑수월가], 가수[탑현]
# 순위[17],제목[눈이 오잖아(Feat.헤이즈)], 가수[이무진]
# 순위[18],제목[STAY], 가수[The Kid LAROI]
# 순위[19],제목[신호등], 가수[이무진]
# 순위[20],제목[Counting Stars (Feat. Beenzino)], 가수[BE'O (비오)]
# 순위[21],제목[다시 사랑한다면 (김필 Ver.)], 가수[임영웅]
# 순위[22],제목[어제처럼], 가수[폴킴]
# 순위[23],제목[Dreams Come True], 가수[aespa]
# 순위[24],제목[Next Level], 가수[aespa]
# 순위[25],제목[strawberry moon], 가수[아이유]
# ...

# %% [markdown]
# # 웹 크롤링 방식 2가지
#
# ### 1. BeautifulSoup 방식
# ### 2. seleniun 방식

# %%
# BeautifulSoup 방식
dfiver =webdriver.Chrome("c:~~~")

url = "http://www.melon.com/cart/index.htm"
driver.get(url)

html = driver.page.source


#이하 부분이 BeautifulSoup 방식 적용
#select() 함수를 이용하여 태그 정보 가지고 오기
soup = beautifulSoul(html, "html.parser")

#순위 10 뽑기
songs = soup.select("tr")[1 : 11]

for i in range(0, len(songs)) :
    #노래 제목만 가지고 오기
    title = songs[i].select("div.ellipsis.rank01 > span > a")[0].text
   
    #가수 이름만 가지고 오기
    singer = songs[i].select("div.ellipsis.rank02 > a")[0].text
    
    #조회
    print("순위[{}],제목[{}], 가수[{}]".format(i+1,title, singer))

# %%
#seleniun 방식(조금 더  빠르다고 함)
dfiver = webdriver.Chrome("C:/Program Files/ChromeDrive_exe/chromedriver.exe")

url = "http://www.melon.com/cart/index.htm"
driver.get(url)

html = driver.page.source


#순위 10 뽑기
songs = driver.find_elemnets_by_css_selecter("tr")[1 : 11]

for i in range(0, len(songs)) :
    #노래 제목만 가지고 오기
    title = songs[i].driver.find_elemnets_by_css_selecter("div.ellipsis.rank01 > span > a")[0].text
   
    #가수 이름만 가지고 오기
    singer = songs[i].driver.find_elemnets_by_css_selecter("div.ellipsis.rank02 > a")[0].text
    
    #조회
    print("순위[{}],제목[{}], 가수[{}]".format(i+1,title, singer))

# %%
driver = webdriver.Chrome("C:/Program Files/ChromeDrive_exe/chromedriver.exe")

url = "https://www.diffordsguide.com/cocktails/20-best"
driver.get(url)
# Out:
# C:\Users\ad\AppData\Local\Temp/ipykernel_11872/1357666209.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/Program Files/ChromeDrive_exe/chromedriver.exe")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11872/1357666209.py in <module>
#       4 driver.get(url)
#       5
# ----> 6 html = driver.page.source
#
# AttributeError: 'WebDriver' object has no attribute 'page'

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <html class="zf-has-scroll is-reveal-open" data-whatclasses="reveal,large alt-font text-grey" data-whatelement="div" data-whatinput="initial" data-whatintent="initial" lang="en" style="top: 0px;"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width" name="viewport"/>
# <title>20 Best Cocktails by Ingredient</title>
# <meta content="The 20 best cocktail recipes by common ingredients." name="description"/>
# <meta content="best, best 20, top 20, top, ingredients, recipes, cocktails, most viewed, Mojito, Margarita, Old Fashioned and Daiquiri, and thousands of other vodka cocktails, gin cocktails, rum cocktails, champagne cocktails, brandy cocktails" name="keywords"/>
# <link href="https://www.diffordsguide.com/en-au/cocktails/20-best" hreflang="en-au" rel="alternate"/>
# <link href="https://www.diffordsguide.com/pt-br/cocktails/20-best" hreflang="pt-br" rel="alternate"/>
# ...

# %%
soup.select("a")
# Out:
# [<a class="colour-inherit text-underline" href="/cookies">use of cookies</a>,
#  <a class="colour-inherit text-underline" href="http://www.enable-javascript.com">here</a>,
#  <a class="cell shrink header-top-bar__item hide always-last-small" href="/shop/basket" id="header-basket">
#  <div class="grid-x">
#  <div class="cell shrink half-pad no-padding-y no-padding-left">
#  <div class="grid-x align-center-middle">
#  <div class="cell shrink">
#  <span class="svg-icon svg-icon--medium svg-icon--cart grid-x align-center-middle">
#  <svg class="cell shrink svg-icon__graphic"><use xlink:href="#icon-cart"></use></svg>
#  </span>
#  </div>
#  <div class="cell shrink pad-left-light svg-icon__label show-for-medium">Basket</div>
#  </div>
#  </div>
#  <div class="cell shrink header-top-bar__basket-count" id="header-basket-count">
#  								1							</div>
#  </div>
#  </a>,
#  <a class="cell shrink header-top-bar__item" href="/shop" id="header-shop-button">
# ...

# %%
soup.select("a.cell.small-6.medium-3.large-2.box")[0]["href"]
# Out:
# '/encyclopedia/2344/cocktails/20-best-angostura-bitters-cocktails'
